# %%
import requests
from bs4 import BeautifulSoup as soup
import re

# %%
def scrapeData(city, province):
    url = 'https://www.remax.ca/{}/{}-real-estate'.format(province, city)
    html = requests.get(url=url)
    html.status_code
    bsobj = soup(html.content,'lxml') 
    return bsobj

# %%
#grab home price from soup object
def getPrice(bsobj):
    price_list = [] 
    for price in bsobj.findAll('h2',{'class':'listing-card_price__sL9TT'}):
        price = ''.join(re.findall(r"\w+", price.get_text().strip()))
        price_list.append(int(price))
    return price_list

# %%
#grab home address from soup object
def getAddress(bsobj):
    price_list = [] 
    for price in bsobj.findAll('div',{'data-cy':'property-address'}):
        price = ' '.join(re.findall(r"[#-,\w]+", price.get_text().strip()))
        price_list.append(price)
    return price_list

# %%
#grab home MLS from soup object
def getMLS(bsobj):
    price_list = [] 
    for price in bsobj.findAll('div', {'class': 'listing-card_mlsNumber__6KRDy'},{'data-cy':'property-mls'}):
        price = re.findall(r"\w+", price.get_text().strip())[1]
        price_list.append(price)
    return price_list

# %%
#grab number of rooms from soup object
def getPropertyFeature(bsobj):
    bed = [] 
    bath = []
    for price in bsobj.findAll('div', {'class': 'property-details_detailsRow__nilLP'}):
        price = re.findall(r"\d+", price.get_text().strip())
        try:
            bed.append(int(price[0]))
        except:
            bed.append(0)
        
        try:
            bath.append(int(price[1]))
        except:
            bath.append(0)
    return bed,bath

# %%
import pandas as pd
df = pd.DataFrame(columns = ['MLS','City','Province','Address', 'Price', 'NumberOfBeds', 'NumberOfBaths'] )
#some random locations for us to scrape, if scraping 2 cities in the same province, we should switch to a list of tuples

queryLocations = [["SK", "Saskatoon"]
                 ,["AB", "Edmonton"]
                 ,["AB", "Calgary"]
                 ,["ON", "Toronto"]
                 ,["ON", "Mississauga"]
                 ,["NS", "Halifax"]
                 ,["BC", "Vancouver"]
                 ,["MB", "Winnipeg"]]

for i in queryLocations:
    province = i[0]
    city = i[1]
    bsobj = scrapeData(city, province)
    price = getPrice(bsobj)
    address = getAddress(bsobj)
    mls = getMLS(bsobj)
    bed, bath = getPropertyFeature(bsobj)
    
    #build a dataframe for each query
    tempDF = pd.DataFrame()
    tempDF['MLS'] = mls
    tempDF['City'] = city
    tempDF['Province'] = province
    tempDF['Address'] = address
    tempDF['Price'] = price
    tempDF['NumberOfBeds'] = bed
    tempDF['NumberOfBaths'] = bath
    print(tempDF)
    df = df.append(tempDF)

print(df)
# Out:
#          MLS       City Province                                    Address  \
# 0   SK914096  Saskatoon       SK              739 L AVENUE S, Saskatoon, SK
# 1   SK914132  Saskatoon       SK           46 Peeling AVENUE, Saskatoon, SK
# 2   SK914089  Saskatoon       SK            115 Ash STREET E, Saskatoon, SK
# 3   SK914075  Saskatoon       SK          334 Crean CRESCENT, Saskatoon, SK
# 4   SK914086  Saskatoon       SK           739 Hastings COVE, Saskatoon, SK
# 5   SK914121  Saskatoon       SK             1227 D AVENUE N, Saskatoon, SK
# 6   SK914104  Saskatoon       SK         2415 Rosewood DRIVE, Saskatoon, SK
# 7   SK914117  Saskatoon       SK         1 927 Heritage VIEW, Saskatoon, SK
# 8   SK914082  Saskatoon       SK         2435 Rosewood DRIVE, Saskatoon, SK
# 9   SK914134  Saskatoon       SK              323 H AVENUE S, Saskatoon, SK
# 10  SK914106  Saskatoon       SK         2427 Rosewood DRIVE, Saskatoon, SK
# 11  SK914056  Saskatoon       SK          3409 Ortona STREET, Saskatoon, SK
# 12  SK914108  Saskatoon       SK                 1 Bow COURT, Saskatoon, SK
# 13  SK913998  Saskatoon       SK           302 Poth CRESCENT, Saskatoon, SK
# 14  SK914012  Saskatoon       SK        652 University DRIVE, Saskatoon, SK
# 15  SK914042  Saskatoon       SK      108 1435 Embassy DRIVE, Saskatoon, SK
# 16  SK914035  Saskatoon       SK        506 537 4th AVENUE N, Saskatoon, SK
# 17  SK914010  Saskatoon       SK  B4 255 Kingsmere BOULEVARD, Saskatoon, SK
# 18  SK914052  Saskatoon       SK         210 Aniskotaw MANOR, Saskatoon, SK
# 19  SK914061  Saskatoon       SK          3104 Ortona STREET, Saskatoon, SK
#
#       Price  NumberOfBeds  NumberOfBaths
# 0    229900             3              2
# 1    329900             4              2
# 2    259900             3              1
# 3    419900             4              3
# 4    899900             4              3
# 5    249900             8              5
# 6    598700             3              3
# 7    509900             2              3
# 8    554300             3              3
# 9    159500             0              0
# 10   632500             4              3
# 11  1275000             6              4
# 12   399000             4              3
# 13   319900             3              3
# 14   599900             5              3
# 15   119900             2              1
# 16   179900             2              1
# 17   129900             2              2
# 18   499900             3              3
# 19   619900             3              3
# C:\Users\Calgary123\AppData\Local\Temp\ipykernel_27732\1707449925.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tempDF)
#          MLS      City Province                                 Address  \
# 0   E4319228  Edmonton       AB          14425 110A AV NW, Edmonton, AB
# 1   A2008195  Edmonton       AB            7224 81 Avenue, Edmonton, AB
# 2   E4318803  Edmonton       AB         9124 141 ST NW NW, Edmonton, AB
# 3   E4318797  Edmonton       AB  #7 15710 BEAUMARIS RD NW, Edmonton, AB
# 4   E4318817  Edmonton       AB            6843 111 ST NW, Edmonton, AB
# 5   E4318811  Edmonton       AB   #602 12303 JASPER AV NW, Edmonton, AB
# 6   E4318805  Edmonton       AB           11710 122 ST NW, Edmonton, AB
# 7   E4318453  Edmonton       AB     #1502 10303 105 ST NW, Edmonton, AB
# 8   E4318462  Edmonton       AB       16 West Point WD NW, Edmonton, AB
# 9   E4318292  Edmonton       AB             9220 75 ST NW, Edmonton, AB
# 10  E4318289  Edmonton       AB      #120 10407 122 ST NW, Edmonton, AB
# 11  E4318264  Edmonton       AB           11134 101 ST NW, Edmonton, AB
# 12  E4318270  Edmonton       AB           12824 130 ST NW, Edmonton, AB
# 13  E4318272  Edmonton       AB            6512 111 AV NW, Edmonton, AB
# 14  E4318286  Edmonton       AB      #809 10142 111 ST NW, Edmonton, AB
# 15  A2004671  Edmonton       AB        12905 66 Street NW, Edmonton, AB
# 16  E4313860  Edmonton       AB            9535 147 AV NW, Edmonton, AB
# 17  E4313357  Edmonton       AB      #105 11716 100 AV NW, Edmonton, AB
# 18  E4312826  Edmonton       AB           12816 124 ST NW, Edmonton, AB
# 19  E4312824  Edmonton       AB            14409 23 ST NW, Edmonton, AB
#
#       Price  NumberOfBeds  NumberOfBaths
# 0    392500             4              3
# 1   1799000             0              0
# 2   1190000             4              3
# 3    189900             3              2
# 4    380000             4              2
# 5    325000             2              2
# 6    389900             3              2
# 7    215000             2              1
# 8   1389900             4              6
# 9    450000             5              4
# 10   234800             2              1
# 11   309900             2              2
# 12   286900             2              1
# 13   835000             5              4
# 14   400000             2              2
# 15   250000             2              1
# 16   295000             4              5
# 17   320000             2              2
# 18   262000             0              0
# 19   175000             0              0
# C:\Users\Calgary123\AppData\Local\Temp\ipykernel_27732\1707449925.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tempDF)
#          MLS     City Province                                        Address  \
# 0   A2009409  Calgary       AB                  253 22 Avenue NW, Calgary, AB
# 1   A2008802  Calgary       AB         159 New Brighton Close SE, Calgary, AB
# 2   A2003495  Calgary       AB               1029 Fonda Court SE, Calgary, AB
# 3   A2005616  Calgary       AB                 1716 42 Street NE, Calgary, AB
# 4   A2011129  Calgary       AB             111 Deerpath Court SE, Calgary, AB
# 5   A2012027  Calgary       AB         1 1720 kensington Road NW, Calgary, AB
# 6   A2011096  Calgary       AB               180 Gordon Drive SW, Calgary, AB
# 7   A2011719  Calgary       AB             2 930 Royal Avenue SW, Calgary, AB
# 8   A2011914  Calgary       AB  1413 151 Country Village Road NE, Calgary, AB
# 9   A2012019  Calgary       AB         27 Hunterhorn Crescent NE, Calgary, AB
# 10  A2007664  Calgary       AB        325 Mckenzie Towne Gate SE, Calgary, AB
# 11  A2009419  Calgary       AB                8 Taraglen Road NE, Calgary, AB
# 12  A1258735  Calgary       AB            4308 13045 6 Street SW, Calgary, AB
# 13  A2010155  Calgary       AB    106 Tuscany Meadows Heights NW, Calgary, AB
# 14  A2004459  Calgary       AB              305 525 13 Avenue SW, Calgary, AB
# 15  A2008620  Calgary       AB             306 1315 12 Avenue SW, Calgary, AB
# 16  A2003939  Calgary       AB             40 Strathcona Road SW, Calgary, AB
# 17  A2009522  Calgary       AB         34 New Brighton Circle SE, Calgary, AB
# 18  A2004597  Calgary       AB      1115 2395 Eversyde Avenue SW, Calgary, AB
# 19  A1255646  Calgary       AB       3101 73 Erin Woods Court SE, Calgary, AB
#
#      Price  NumberOfBeds  NumberOfBaths
# 0   629999             2              2
# 1   689900             5              4
# 2   299900             4              2
# 3   519900             4              3
# 4   399000             3              2
# 5   575000             3              4
# 6   499900             3              2
# 7   199900             2              1
# 8   340000             1              1
# 9   349900             3              2
# 10  374900             3              3
# 11  439900             3              2
# 12  174900             2              1
# 13  924888             4              4
# 14  159900             1              1
# 15  294900             2              2
# 16  699900             3              3
# 17  559900             3              3
# 18  224900             2              1
# 19  209900             2              2
# C:\Users\Calgary123\AppData\Local\Temp\ipykernel_27732\1707449925.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tempDF)
#          MLS     City Province                                        Address  \
# 0   C5827918  Toronto       ON               #423 1005 KING ST W, Toronto, ON
# 1   W5827885  Toronto       ON                 11 SUNNYBRAE CRES, Toronto, ON
# 2   C5827921  Toronto       ON                  #714 629 KING ST, Toronto, ON
# 3   W5827929  Toronto       ON                 38 VEROBEACH BLVD, Toronto, ON
# 4   W5827880  Toronto       ON                  51 BURNFIELD AVE, Toronto, ON
# 5   C5827952  Toronto       ON            #ON 2007 HILLCREST AVE, Toronto, ON
# 6   W5827886  Toronto       ON           #1012 816 LANSDOWNE AVE, Toronto, ON
# 7   E5826980  Toronto       ON  #304 452 SCARBOROUGH GOLFCLUB RD, Toronto, ON
# 8   C5827246  Toronto       ON           #PH05 15 FORT YORK BLVD, Toronto, ON
# 9   W5827399  Toronto       ON                    33 WICKFORD DR, Toronto, ON
# 10  C5827589  Toronto       ON                     137 SEATON ST, Toronto, ON
# 11  E5827590  Toronto       ON                       411 MAIN ST, Toronto, ON
# 12  C5827612  Toronto       ON            #1405 70 TEMPERANCE ST, Toronto, ON
# 13  W5827624  Toronto       ON                   173 WALLACE AVE, Toronto, ON
# 14  C5827707  Toronto       ON                    244 BENSON AVE, Toronto, ON
# 15  C5827219  Toronto       ON                   #809 70 MILL ST, Toronto, ON
# 16  W5827724  Toronto       ON                #213 2772 KEELE ST, Toronto, ON
# 17  C5827323  Toronto       ON               #1406 10 BELLAIR ST, Toronto, ON
# 18  C5827831  Toronto       ON                   #2808 33 BAY ST, Toronto, ON
# 19  W5826908  Toronto       ON              #213 20 SOUTHPORT ST, Toronto, ON
#
#       Price  NumberOfBeds  NumberOfBaths
# 0    629000             1              1
# 1   1199000             3              2
# 2    629000             1              1
# 3    848888             4              2
# 4   2350000             3              4
# 5    795000             2              2
# 6    729900             2              2
# 7    408000             2              2
# 8   3750000             3              3
# 9   1879000             5              5
# 10  1780000             3              3
# 11   599000             2              1
# 12   480000             0              1
# 13  1699000             5              4
# 14  1569000             3              2
# 15   839000             2              2
# 16   499000             2              1
# 17  1539900             2              2
# 18  1258000             3              2
# 19   569000             2              2
# C:\Users\Calgary123\AppData\Local\Temp\ipykernel_27732\1707449925.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tempDF)
#          MLS         City Province  \
# 0   W5827909  Mississauga       ON
# 1   W5827928  Mississauga       ON
# 2   W5827892  Mississauga       ON
# 3   W5827911  Mississauga       ON
# 4   W5827935  Mississauga       ON
# 5   W5827299  Mississauga       ON
# 6   W5827400  Mississauga       ON
# 7   40349553  Mississauga       ON
# 8   W5827557  Mississauga       ON
# 9   W5827674  Mississauga       ON
# 10  40349719  Mississauga       ON
# 11  W5826905  Mississauga       ON
# 12  W5826773  Mississauga       ON
# 13  W5826834  Mississauga       ON
# 14  W5827351  Mississauga       ON
# 15  W5827448  Mississauga       ON
# 16  H4151093  Mississauga       ON
# 17  40349185  Mississauga       ON
# 18  W5826874  Mississauga       ON
# 19  W5827446  Mississauga       ON
#
#                                               Address    Price  NumberOfBeds  \
# 0                 3179 IBBETSON CRES, Mississauga, ON  1100000             4
# 1                #2109 1 VALHALLA INN RD, Toronto, ON   729900             3
# 2                     38 ROYAL VISTA RD, Brampton, ON   915000             4
# 3                        80A CORBY CRES, Brampton, ON   699000             3
# 4                         50 ERINGATE DR, Toronto, ON   949000             3
# 5                       660 ARBOR RD, Mississauga, ON   999000             4
# 6          3259 SCOTCH PINE GATE AVE, Mississauga, ON  1259000             5
# 7               1457 WAKEHURST Crescent, Oakville, ON  1479000             4
# 8               #3203 208 ENFIELD PL, Mississauga, ON   736888             2
# 9              #30 6860 GLEN ERIN DR, Mississauga, ON   789900             4
# 10  4085 PARKSIDE VILLAGE Drive Unit# 310, Mississ...   749900             2
# 11                 938 BLAIRHOLM AVE, Mississauga, ON   999000             4
# 12              2358 COBBINSHAW CIRC, Mississauga, ON  1089000             4
# 13                 1425 CHRISEDEN DR, Mississauga, ON  4125000             4
# 14                     128 PARK ST E, Mississauga, ON  1219000             3
# 15                      63 VIVIANS CRES, Brampton, ON  1024990             3
# 16      80 ABSOLUTE Avenue Unit #311, Mississauga, ON   569420             1
# 17                    53 RAYSIDE Drive, Etobicoke, ON  1199919             5
# 18                       52A TREEVIEW DR, Toronto, ON  1428800             4
# 19                      11 ROSEMEADE AVE, Toronto, ON  1349900             5
#
#     NumberOfBaths
# 0               3
# 1               2
# 2               4
# 3               3
# 4               2
# 5               3
# 6               4
# 7               3
# 8               2
# 9               3
# 10              2
# 11              3
# 12              3
# 13              5
# 14              4
# 15              3
# 16              2
# 17              2
# 18              4
# 19              3
# C:\Users\Calgary123\AppData\Local\Temp\ipykernel_27732\1707449925.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tempDF)
# Empty DataFrame
# Columns: [MLS, City, Province, Address, Price, NumberOfBeds, NumberOfBaths]
# Index: []
# C:\Users\Calgary123\AppData\Local\Temp\ipykernel_27732\1707449925.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tempDF)
#          MLS       City Province  \
# 0   R2738520  Vancouver       BC
# 1   R2738552  Vancouver       BC
# 2   R2738530  Vancouver       BC
# 3   R2738528  Vancouver       BC
# 4   R2738554  Vancouver       BC
# 5   R2738518  Vancouver       BC
# 6   R2738548  Vancouver       BC
# 7   R2738556  Vancouver       BC
# 8   R2738581  Vancouver       BC
# 9   R2738546  Vancouver       BC
# 10  R2738543  Vancouver       BC
# 11  R2738527  Vancouver       BC
# 12  X5826720  Vancouver       BC
# 13  R2738231  Vancouver       BC
# 14  C8047859  Vancouver       BC
# 15  R2738215  Vancouver       BC
# 16  R2738301  Vancouver       BC
# 17  R2738168  Vancouver       BC
# 18  R2738296  Vancouver       BC
# 19  R2738293  Vancouver       BC
#
#                                          Address     Price  NumberOfBeds  \
# 0        805 1225 RICHARDS STREET, Vancouver, BC    574999             0
# 1             208 8070 OAK STREET, Vancouver, BC   1179700             2
# 2         1106 5629 BIRNEY AVENUE, Vancouver, BC   1319000             2
# 3        1278 DUCHESS AVENUE, West Vancouver, BC   2198000             3
# 4            3206 CAROLINA STREET, Vancouver, BC   2198000             6
# 5         2005 4388 BUCHANAN STREET, Burnaby, BC    849900             2
# 6             201 8070 OAK STREET, Vancouver, BC    917700             1
# 7             202 8030 OAK STREET, Vancouver, BC   1379800             3
# 8        605 53 W HASTINGS STREET, Vancouver, BC    875000             1
# 9             102 8030 OAK STREET, Vancouver, BC    698800             1
# 10           3206 CAROLINA STREET, Vancouver, BC   2198000             6
# 11  167 2035 GLENAIRE DRIVE, North Vancouver, BC   1159000             3
# 12             3616 POINT GREY RD, Vancouver, BC   4880000             4
# 13        PH1 1550 ALBERNI STREET, Vancouver, BC  31880800             3
# 14                    6401 KINGSWAY, Burnaby, BC  12800000             0
# 15      3403 1189 MELVILLE STREET, Vancouver, BC   2848000             3
# 16       204 565 17TH STREET, West Vancouver, BC   1150000             2
# 17       1403 1818 ALBERNI STREET, Vancouver, BC   2269900             2
# 18    2002 1550 FERN STREET, North Vancouver, BC    924000             2
# 19         101 5615 HAMPTON PLACE, Vancouver, BC   1050000             2
#
#     NumberOfBaths
# 0               1
# 1               2
# 2               2
# 3               3
# 4               5
# 5               2
# 6               1
# 7               2
# 8               1
# 9               1
# 10              5
# 11              2
# 12              3
# 13              5
# 14              0
# 15              3
# 16              2
# 17              2
# 18              2
# 19              2
# C:\Users\Calgary123\AppData\Local\Temp\ipykernel_27732\1707449925.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tempDF)
#           MLS      City Province                                Address  \
# 0   202226988  Winnipeg       MB           13 Hull Avenue, Winnipeg, MB
# 1   202227043  Winnipeg       MB     190 Springwater Road, Winnipeg, MB
# 2   202227026  Winnipeg       MB    680 Wellington Avenue, Winnipeg, MB
# 3   202227027  Winnipeg       MB        475 Besant Street, Winnipeg, MB
# 4   202227046  Winnipeg       MB        669 Alfred Avenue, Winnipeg, MB
# 5   202224448  Winnipeg       MB          38 Inman Avenue, Winnipeg, MB
# 6   202226958  Winnipeg       MB  32 SOUTHLANDS Drive, East St Paul, MB
# 7   202226877  Winnipeg       MB     55 Forestgate Avenue, Winnipeg, MB
# 8   202226999  Winnipeg       MB        32 Crystal Avenue, Winnipeg, MB
# 9   202227009  Winnipeg       MB          206 Yale Avenue, Winnipeg, MB
# 10  202225990  Winnipeg       MB          20 Whidden Gate, Winnipeg, MB
# 11  202226895  Winnipeg       MB           34 Hood Avenue, Winnipeg, MB
# 12  202227006  Winnipeg       MB        207 Edward Avenue, Winnipeg, MB
# 13  202226121  Winnipeg       MB      58 Lindenwood Drive, Winnipeg, MB
# 14  202226911  Winnipeg       MB        21 DISCOVERY Cove, Winnipeg, MB
# 15  202226898  Winnipeg       MB         251 Cullen Drive, Winnipeg, MB
# 16  202226907  Winnipeg       MB      150 Nordstrom Drive, Winnipeg, MB
# 17  202226946  Winnipeg       MB      789 Sherburn Street, Winnipeg, MB
# 18  202225745  Winnipeg       MB      389 Beverley Street, Winnipeg, MB
# 19  202225532  Winnipeg       MB         11 Crocker Place, Winnipeg, MB
#
#       Price  NumberOfBeds  NumberOfBaths
# 0    349900             2              1
# 1    674900             3              3
# 2    629000             0              0
# 3    349000             4              2
# 4    169900             3              1
# 5    270000             2              1
# 6   1057000             5              3
# 7    499000             3              2
# 8    198700             2              1
# 9    229900             2              1
# 10   599900             4              3
# 11   434900             3              3
# 12   319900             3              1
# 13   649900             4              3
# 14  1490000             6              5
# 15   349900             4              2
# 16   499900             3              3
# 17   229900             2              1
# 18    74900             3              1
# 19   899900             4              3
#           MLS       City Province                            Address   Price  \
# 0    SK914096  Saskatoon       SK      739 L AVENUE S, Saskatoon, SK  229900
# 1    SK914132  Saskatoon       SK   46 Peeling AVENUE, Saskatoon, SK  329900
# 2    SK914089  Saskatoon       SK    115 Ash STREET E, Saskatoon, SK  259900
# 3    SK914075  Saskatoon       SK  334 Crean CRESCENT, Saskatoon, SK  419900
# 4    SK914086  Saskatoon       SK   739 Hastings COVE, Saskatoon, SK  899900
# ..        ...        ...      ...                                ...     ...
# 15  202226898   Winnipeg       MB     251 Cullen Drive, Winnipeg, MB  349900
# 16  202226907   Winnipeg       MB  150 Nordstrom Drive, Winnipeg, MB  499900
# 17  202226946   Winnipeg       MB  789 Sherburn Street, Winnipeg, MB  229900
# 18  202225745   Winnipeg       MB  389 Beverley Street, Winnipeg, MB   74900
# 19  202225532   Winnipeg       MB     11 Crocker Place, Winnipeg, MB  899900
#
#    NumberOfBeds NumberOfBaths
# 0             3             2
# 1             4             2
# 2             3             1
# 3             4             3
# 4             4             3
# ..          ...           ...
# 15            4             2
# 16            3             3
# 17            2             1
# 18            3             1
# 19            4             3
#
# [140 rows x 7 columns]
# C:\Users\Calgary123\AppData\Local\Temp\ipykernel_27732\1707449925.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tempDF)

# %%
df =df[(df.NumberOfBeds != 0) & (df.NumberOfBaths != 0)]

# %%
df
# Out:
#           MLS       City Province                            Address   Price  \
# 0    SK914096  Saskatoon       SK      739 L AVENUE S, Saskatoon, SK  229900
# 1    SK914132  Saskatoon       SK   46 Peeling AVENUE, Saskatoon, SK  329900
# 2    SK914089  Saskatoon       SK    115 Ash STREET E, Saskatoon, SK  259900
# 3    SK914075  Saskatoon       SK  334 Crean CRESCENT, Saskatoon, SK  419900
# 4    SK914086  Saskatoon       SK   739 Hastings COVE, Saskatoon, SK  899900
# ..        ...        ...      ...                                ...     ...
# 15  202226898   Winnipeg       MB     251 Cullen Drive, Winnipeg, MB  349900
# 16  202226907   Winnipeg       MB  150 Nordstrom Drive, Winnipeg, MB  499900
# 17  202226946   Winnipeg       MB  789 Sherburn Street, Winnipeg, MB  229900
# 18  202225745   Winnipeg       MB  389 Beverley Street, Winnipeg, MB   74900
# 19  202225532   Winnipeg       MB     11 Crocker Place, Winnipeg, MB  899900
#
#    NumberOfBeds NumberOfBaths
# 0             3             2
# 1             4             2
# 2             3             1
# 3             4             3
# 4             4             3
# ..          ...           ...
# 15            4             2
# 16            3             3
# 17            2             1
# 18            3             1
# 19            4             3
#
# [132 rows x 7 columns]

# %%
df.to_csv('remax_properties.csv')
